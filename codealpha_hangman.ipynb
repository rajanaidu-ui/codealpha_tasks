# %%
import random

# List of predefined words
words = ["python", "computer", "program", "keyboard", "monitor", "laptop", "mouse", "words", ]

# Choose a random word
word = random.choice(words)

# Store guessed letters
guessed_letters = []
incorrect_guesses = 0
max_guesses = 6

print("===== Welcome to Hangman Game =====")

while incorrect_guesses < max_guesses:
    # Display the word with underscores
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter + " "
        else:
            display += "_ "

    print("\nWord:", display)

    # Check if player has guessed the word
    if "_" not in display:
        print("🎉 Congratulations! You guessed the word:", word)
        break

    # Get user input
    guess = input("Enter a letter: ").lower()

    # Validate input
    if len(guess) != 1 or not guess.isalpha():
        print("Please enter only one alphabet letter.")
        continue

    if guess in guessed_letters:
        print("You already guessed that letter.")
        continue

    guessed_letters.append(guess)

    if guess in word:
        print("Correct!")
    else:
        incorrect_guesses += 1
        print("Wrong guess!")
        print("Remaining guesses:", max_guesses - incorrect_guesses)

# If player loses
if incorrect_guesses == max_guesses:
    print("\nGame Over!")
    print("The correct word was:", word)
# Out:
# ===== Welcome to Hangman Game =====
#
# Word: _ _ _ _ _
# Enter a letter: c
# Wrong guess!
# Remaining guesses: 5
#
# Word: _ _ _ _ _
# Enter a letter: o
# Correct!
#
# Word: _ o _ _ _
# Enter a letter: m
# Correct!
#
# Word: m o _ _ _
# Enter a letter: u
# Correct!
#
# Word: m o u _ _
# Enter a letter: s
# Correct!
#
# Word: m o u s _
# Enter a letter: e
# Correct!
#
# Word: m o u s e
# 🎉 Congratulations! You guessed the word: mouse
